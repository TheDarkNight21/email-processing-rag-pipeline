# %%
# !pip install raganything
# Out:
# Collecting raganything
#   Downloading raganything-1.2.8-py3-none-any.whl.metadata (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from raganything) (0.35.0)
# Collecting lightrag-hku (from raganything)
#   Downloading lightrag_hku-1.4.8.2-py3-none-any.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.1 MB/s eta 0:00:00
# Collecting mineru[core] (from raganything)
#   Downloading mineru-2.5.3-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from raganything) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->raganything) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->raganything) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->raganything) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->raganything) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->raganything) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->raganything) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->raganything) (1.1.10)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (3.12.15)
# Collecting configparser (from lightrag-hku->raganything)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting dotenv (from lightrag-hku->raganything)
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (1.0.0)
# Collecting json_repair (from lightrag-hku->raganything)
#   Downloading json_repair-0.51.0-py3-none-any.whl.metadata (11 kB)
# Collecting nano-vectordb (from lightrag-hku->raganything)
#   Downloading nano_vectordb-0.0.4.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (2.2.2)
# Collecting pipmaster (from lightrag-hku->raganything)
#   Downloading pipmaster-1.0.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (2.11.9)
# Collecting pypinyin (from lightrag-hku->raganything)
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (75.2.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (8.5.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from lightrag-hku->raganything) (0.11.0)
# Collecting xlsxwriter>=3.1.0 (from lightrag-hku->raganything)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Collecting boto3>=1.28.43 (from mineru[core]->raganything)
#   Downloading boto3-1.40.37-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (8.2.1)
# Collecting loguru>=0.7.2 (from mineru[core]->raganything)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting pdfminer.six==20250506 (from mineru[core]->raganything)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (0.28.1)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (11.3.0)
# Collecting pypdfium2>=4.30.0 (from mineru[core]->raganything)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.3 MB/s eta 0:00:00
# Collecting pypdf>=5.6.0 (from mineru[core]->raganything)
#   Downloading pypdf-6.1.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting reportlab (from mineru[core]->raganything)
#   Downloading reportlab-4.4.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting pdftext>=0.6.2 (from mineru[core]->raganything)
#   Downloading pdftext-0.6.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting modelscope>=1.26.0 (from mineru[core]->raganything)
#   Downloading modelscope-1.30.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (4.12.0.88)
# Collecting fast-langdetect<0.3.0,>=0.2.3 (from mineru[core]->raganything)
#   Downloading fast_langdetect-0.2.5-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: scikit-image<1.0.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (0.25.2)
# Requirement already satisfied: openai<2,>=1.70.0 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (1.108.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.13.5 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (4.13.5)
# Collecting magika<0.7.0,>=0.6.2 (from mineru[core]->raganything)
#   Downloading magika-0.6.2-py3-none-manylinux_2_28_x86_64.whl.metadata (15 kB)
# Collecting mineru-vl-utils<1,>=0.1.8 (from mineru[core]->raganything)
#   Downloading mineru_vl_utils-0.1.11-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20250506->mineru[core]->raganything) (3.4.3)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20250506->mineru[core]->raganything) (43.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=4.13.5->mineru[core]->raganything) (2.8)
# Collecting botocore<1.41.0,>=1.40.37 (from boto3>=1.28.43->mineru[core]->raganything)
#   Downloading botocore-1.40.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.28.43->mineru[core]->raganything)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3>=1.28.43->mineru[core]->raganything)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting robust-downloader>=0.0.2 (from fast-langdetect<0.3.0,>=0.2.3->mineru[core]->raganything)
#   Downloading robust_downloader-0.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting fasttext-predict>=0.9.2.4 (from fast-langdetect<0.3.0,>=0.2.3->mineru[core]->raganything)
#   Downloading fasttext_predict-0.9.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting onnxruntime>=1.17.0 (from magika<0.7.0,>=0.6.2->mineru[core]->raganything)
#   Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from mineru-vl-utils<1,>=0.1.8->mineru[core]->raganything) (24.1.0)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.12/dist-packages (from modelscope>=1.26.0->mineru[core]->raganything) (2.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.70.0->mineru[core]->raganything) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.70.0->mineru[core]->raganything) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.70.0->mineru[core]->raganything) (0.11.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.70.0->mineru[core]->raganything) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->mineru[core]->raganything) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->mineru[core]->raganything) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->mineru[core]->raganything) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->mineru[core]->raganything) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->lightrag-hku->raganything) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->lightrag-hku->raganything) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->lightrag-hku->raganything) (2025.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from pdftext>=0.6.2->mineru[core]->raganything) (2.10.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->lightrag-hku->raganything) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->lightrag-hku->raganything) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->lightrag-hku->raganything) (0.4.1)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[core]->raganything) (1.16.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[core]->raganything) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[core]->raganything) (2025.9.9)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[core]->raganything) (0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku->raganything) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku->raganything) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku->raganything) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku->raganything) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku->raganything) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku->raganything) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku->raganything) (1.20.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (0.116.2)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (0.0.20)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (0.35.0)
# Requirement already satisfied: gradio<6,>=5.34 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (5.46.0)
# Collecting gradio-pdf>=0.0.22 (from mineru[core]->raganything)
#   Downloading gradio_pdf-0.0.22-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (3.10.0)
# Collecting ultralytics<9,>=8.3.48 (from mineru[core]->raganything)
#   Downloading ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
# Collecting doclayout_yolo==0.0.4 (from mineru[core]->raganything)
#   Downloading doclayout_yolo-0.0.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: dill<1,>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (0.3.8)
# Collecting ftfy<7,>=6.3.1 (from mineru[core]->raganything)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: shapely<3,>=2.0.7 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (2.1.1)
# Collecting pyclipper<2,>=1.3.0 (from mineru[core]->raganything)
#   Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: omegaconf<3,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (2.3.0)
# Requirement already satisfied: torch<3,>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (0.23.0+cu126)
# Requirement already satisfied: transformers!=4.51.0,<5.0.0,>=4.49.0 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (4.56.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from doclayout_yolo==0.0.4->mineru[core]->raganything) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from doclayout_yolo==0.0.4->mineru[core]->raganything) (9.0.0)
# Collecting thop>=0.1.1 (from doclayout_yolo==0.0.4->mineru[core]->raganything)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from doclayout_yolo==0.0.4->mineru[core]->raganything) (0.13.2)
# Requirement already satisfied: albumentations>=1.4.11 in /usr/local/lib/python3.12/dist-packages (from doclayout_yolo==0.0.4->mineru[core]->raganything) (2.0.8)
# Requirement already satisfied: accelerate>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from mineru[core]->raganything) (1.10.1)
# Collecting ascii_colors>=0.8.0 (from pipmaster->lightrag-hku->raganything)
#   Downloading ascii_colors-0.11.4-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->lightrag-hku->raganything) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.5.1->mineru[core]->raganything) (0.6.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ascii_colors>=0.8.0->pipmaster->lightrag-hku->raganything) (0.2.13)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->mineru[core]->raganything) (2.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (1.1.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.6.1)
# Requirement already satisfied: gradio-client==1.13.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (1.13.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.1.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (3.11.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.25.1)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.13.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio<6,>=5.34->mineru[core]->raganything) (0.17.4)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.0->gradio<6,>=5.34->mineru[core]->raganything) (15.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[core]->raganything) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[core]->raganything) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[core]->raganything) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[core]->raganything) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[core]->raganything) (3.2.4)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3,>=2.3.0->mineru[core]->raganything) (4.9.3)
# Collecting coloredlogs (from onnxruntime>=1.17.0->magika<0.7.0,>=0.6.2->mineru[core]->raganything)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->magika<0.7.0,>=0.6.2->mineru[core]->raganything) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->magika<0.7.0,>=0.6.2->mineru[core]->raganything) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->magika<0.7.0,>=0.6.2->mineru[core]->raganything) (1.13.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->lightrag-hku->raganything) (1.17.0)
# Collecting colorlog (from robust-downloader>=0.0.2->fast-langdetect<0.3.0,>=0.2.3->mineru[core]->raganything)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.6.0->mineru[core]->raganything) (3.4.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->mineru[core]->raganything) (0.22.0)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics<9,>=8.3.48->mineru[core]->raganything) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics<9,>=8.3.48->mineru[core]->raganything)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru[core]->raganything) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru[core]->raganything) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru[core]->raganything) (4.0.11)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru[core]->raganything) (6.5.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->mineru[core]->raganything) (2.23)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.17.0->magika<0.7.0,>=0.6.2->mineru[core]->raganything) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<6,>=5.34->mineru[core]->raganything) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<6,>=5.34->mineru[core]->raganything) (13.9.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.17.0->magika<0.7.0,>=0.6.2->mineru[core]->raganything)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6,>=5.34->mineru[core]->raganything) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6,>=5.34->mineru[core]->raganything) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio<6,>=5.34->mineru[core]->raganything) (0.1.2)
# Downloading raganything-1.2.8-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 kB 5.8 MB/s eta 0:00:00
# Downloading lightrag_hku-1.4.8.2-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 37.0 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 77.5 MB/s eta 0:00:00
# Downloading boto3-1.40.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 9.1 MB/s eta 0:00:00
# Downloading fast_langdetect-0.2.5-py3-none-any.whl (786 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.6/786.6 kB 41.7 MB/s eta 0:00:00
# Downloading json_repair-0.51.0-py3-none-any.whl (26 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.0 MB/s eta 0:00:00
# Downloading magika-0.6.2-py3-none-manylinux_2_28_x86_64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 77.6 MB/s eta 0:00:00
# Downloading mineru_vl_utils-0.1.11-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
# Downloading modelscope-1.30.0-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 99.8 MB/s eta 0:00:00
# Downloading pdftext-0.6.3-py3-none-any.whl (23 kB)
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 86.4 MB/s eta 0:00:00
# Downloading pypdf-6.1.0-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 17.8 MB/s eta 0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 12.2 MB/s eta 0:00:00
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading mineru-2.5.3-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.2 MB/s eta 0:00:00
# Downloading doclayout_yolo-0.0.4-py3-none-any.whl (711 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.3/711.3 kB 38.3 MB/s eta 0:00:00
# Downloading nano_vectordb-0.0.4.3-py3-none-any.whl (5.6 kB)
# Downloading pipmaster-1.0.4-py3-none-any.whl (26 kB)
# Downloading pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 33.2 MB/s eta 0:00:00
# Downloading reportlab-4.4.4-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.9 MB/s eta 0:00:00
# Downloading ascii_colors-0.11.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 4.6 MB/s eta 0:00:00
# Downloading botocore-1.40.37-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 101.3 MB/s eta 0:00:00
# Downloading fasttext_predict-0.9.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.1/296.1 kB 19.5 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.8 MB/s eta 0:00:00
# Downloading gradio_pdf-0.0.22-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.4 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 52.4 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 45.2 MB/s eta 0:00:00
# Downloading robust_downloader-0.0.2-py3-none-any.whl (15 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 4.9 MB/s eta 0:00:00
# Downloading ultralytics-8.3.203-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.6 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: pyclipper, fasttext-predict, xlsxwriter, reportlab, pypinyin, pypdfium2, pypdf, nano-vectordb, loguru, json_repair, jmespath, humanfriendly, ftfy, dotenv, configparser, colorlog, ascii_colors, robust-downloader, pipmaster, modelscope, coloredlogs, botocore, s3transfer, pdfminer.six, onnxruntime, mineru-vl-utils, lightrag-hku, fast-langdetect, ultralytics-thop, thop, pdftext, magika, boto3, ultralytics, mineru, gradio-pdf, doclayout_yolo, raganything
# Successfully installed ascii_colors-0.11.4 boto3-1.40.37 botocore-1.40.37 coloredlogs-15.0.1 colorlog-6.9.0 configparser-7.2.0 doclayout_yolo-0.0.4 dotenv-0.9.9 fast-langdetect-0.2.5 fasttext-predict-0.9.2.4 ftfy-6.3.1 gradio-pdf-0.0.22 humanfriendly-10.0 jmespath-1.0.1 json_repair-0.51.0 lightrag-hku-1.4.8.2 loguru-0.7.3 magika-0.6.2 mineru-2.5.3 mineru-vl-utils-0.1.11 modelscope-1.30.0 nano-vectordb-0.0.4.3 onnxruntime-1.22.1 pdfminer.six-20250506 pdftext-0.6.3 pipmaster-1.0.4 pyclipper-1.3.0.post6 pypdf-6.1.0 pypdfium2-4.30.0 pypinyin-0.55.0 raganything-1.2.8 reportlab-4.4.4 robust-downloader-0.0.2 s3transfer-0.14.0 thop-0.1.1.post2209072238 ultralytics-8.3.203 ultralytics-thop-2.0.17 xlsxwriter-3.2.9

# %% [markdown]
# # Email RAG Pipeline
#
# This notebook demonstrates a simple RAG (Retrieval-Augmented Generation) pipeline for processing downloaded Outlook emails.

# %%
import os
import email
import json
from pathlib import Path
from typing import Dict, List, Any
import pandas as pd

# For vector operations (you'll need to install these)
import numpy as np
#from sentence_transformers import SentenceTransformer
#import faiss

import asyncio
from raganything import RAGAnything, RAGAnythingConfig
from lightrag.llm.openai import openai_complete_if_cache, openai_embed
from lightrag.utils import EmbeddingFunc

# %% [markdown]
# ## 1. Load Email Files from Local Directory
#
# Load your downloaded Outlook email files (.eml, .msg, or .pst files) from a local directory

# %%
import os
from pathlib import Path
from google.colab import drive

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Point to the directory in Drive where your emails are stored
# Make sure you created this folder inside your Drive and uploaded .eml/.msg/.pst files there
email_directory = "/content/drive/My Drive/MMV_email_rag/raw_emails"
rag_storage_directory = "/content/drive/My Drive/MMV_email_rag/rag_storage"
email_texts_directory = "/content/drive/My Drive/MMV_email_rag/email_texts"

# Step 3: Collect all email paths
email_paths = {}
email_files = []

if os.path.exists(email_directory):
    for ext in ['*.eml', '*.msg', '*.pst']:
        email_files.extend(Path(email_directory).glob(ext))

    for i, file_path in enumerate(email_files):
        email_paths[f"Email-{i+1}"] = str(file_path)

    print(f"Found {len(email_paths)} email files in {email_directory}:")
    for name, path in email_paths.items():
        print(f"  {name}: {os.path.basename(path)}")
else:
    print(f"Directory {email_directory} not found!")
    print("Please create the directory in Google Drive and upload your email files there.")
    print("Example: Place your files in 'My Drive/raw_emails'")
# Out:
# Mounted at /content/drive
# Found 9 email files in /content/drive/My Drive/MMV_email_rag/raw_emails:
#   Email-1: First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank.eml
#   Email-2: Invitation to Bid - Burlington - Louisville, KY _ Bids Due 10_15_25.eml
#   Email-3: Fw_ Follow Up_ Invitation To Bid - Heartland Dental - Shelby Township, MI TI.eml
#   Email-4: RE_ Invitation to Bid -  Bath & Body Works #5027 - Burton, MI.eml
#   Email-5: INVITATION TO BID_ AutoZone - Weston, WV.eml
#   Email-6: Fw_ Grosse Ile Country Club Pool House Renovation Invitation To Bid.eml
#   Email-7: Invitation to Bid - Tractor Supply - Johnstown, OH.eml
#   Email-8: Fw_ Kresge Eye Institute - bathrooms renovation; 29201 Telegraph Road, Southfield MI 48034.eml
#   Email-9: Fw_ INVITATION TO BID - 115_230 E. Hudson Avenue, Royal Oak MI 48067.eml

# %% [markdown]
# ## 2. Email Parsing Functions

# %%
import os
import re
from pathlib import Path
from email import policy
from email.parser import BytesParser


def eml_to_text(eml_path):
    """Convert an .eml file into a flattened string."""
    with open(eml_path, 'rb') as f:
        msg = BytesParser(policy=policy.default).parse(f)

    subject = (msg.get('Subject') or '').strip()
    sender = (msg.get('From') or '').strip()
    recipients = ", ".join(msg.get_all('To', []) or [])
    date = (msg.get('Date') or '').strip()

    # Extract body (prefer plain text, fallback to stripped HTML)
    body_text = ""
    if msg.is_multipart():
        for part in msg.walk():
            if part.get_content_disposition() == 'attachment':
                continue
            if part.get_content_type() == 'text/plain':
                body_text += part.get_content() or ''
            elif part.get_content_type() == 'text/html' and not body_text:
                html = part.get_content() or ''
                body_text = re.sub(r'<[^>]+>', ' ', html)
    else:
        body_text = msg.get_content() or ''

    body_text = re.sub(r'\s+', ' ', body_text).strip()

    email_text = (
        f"subject: {subject}\n"
        f"from: {sender}\n"
        f"to: {recipients}\n"
        f"date: {date}\n\n"
        f"body:\n{body_text}\n"
    )
    return email_text, subject


def save_emails_as_txt(email_dir, output_dir):
    """Convert .eml files into plain text .txt files for RAG ingestion."""
    os.makedirs(output_dir, exist_ok=True)
    email_files = list(Path(email_dir).glob("*.eml"))

    saved_txts = []

    for i, eml_file in enumerate(email_files, 1):
        email_text, subject = eml_to_text(eml_file)

        safe_subject = re.sub(r'[\\/*?:"<>|]', "_", subject).strip() or f"Email_{i}"
        txt_filename = os.path.join(output_dir, f"{safe_subject}_{i}.txt")

        with open(txt_filename, "w", encoding="utf-8") as f:
            f.write(email_text)

        saved_txts.append(txt_filename)
        print(f"Saved {txt_filename}")

    return saved_txts

saved_text_files = save_emails_as_txt(email_directory, email_texts_directory)

print("\nAll saved text files:")
for txt in saved_text_files:
    print(txt)
# Out:
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/Invitation to Bid - Burlington - Louisville, KY _ Bids Due 10_15_25_2.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ Follow Up_ Invitation To Bid - Heartland Dental - Shelby Township, MI TI_3.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/RE_ Invitation to Bid -  Bath & Body Works #5027 - Burton, MI_4.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/INVITATION TO BID_ AutoZone - Weston, WV_5.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ Grosse Ile Country Club Pool House Renovation Invitation To Bid_6.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/Invitation to Bid - Tractor Supply - Johnstown, OH_7.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ Kresge Eye Institute - bathrooms renovation; 29201 Telegraph Road, Southfield MI 48034_8.txt
# Saved /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ INVITATION TO BID - 115_230 E. Hudson Avenue, Royal Oak MI 48067_9.txt
#
# All saved text files:
# /content/drive/My Drive/MMV_email_rag/email_texts/First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/Invitation to Bid - Burlington - Louisville, KY _ Bids Due 10_15_25_2.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ Follow Up_ Invitation To Bid - Heartland Dental - Shelby Township, MI TI_3.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/RE_ Invitation to Bid -  Bath & Body Works #5027 - Burton, MI_4.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/INVITATION TO BID_ AutoZone - Weston, WV_5.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ Grosse Ile Country Club Pool House Renovation Invitation To Bid_6.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/Invitation to Bid - Tractor Supply - Johnstown, OH_7.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ Kresge Eye Institute - bathrooms renovation; 29201 Telegraph Road, Southfield MI 48034_8.txt
# /content/drive/My Drive/MMV_email_rag/email_texts/Fw_ INVITATION TO BID - 115_230 E. Hudson Avenue, Royal Oak MI 48067_9.txt

# %% [markdown]
# info i need to get out of email (including pdf's later, for now just text) for lead input in sage:
#
# 1. name of project
# 2. bid due date and time
# 3. address/location of project
# 4. general contractor (origin of email)
# 5. contact of general contractor (person who sent the email's first and last name)
# 6. anything to take note of (site walkthrough time, estimated start date of construction, etc)

# %%
from pathlib import Path
from google.colab import userdata

async def example_raganything():
    api_key = userdata.get('OPENAI_API_KEY')

    # Config
    config = RAGAnythingConfig(
        working_dir=rag_storage_directory,
        parser="mineru",
        parse_method="txt",   # Force text parsing
        enable_image_processing=False,
        enable_table_processing=False,
        enable_equation_processing=False,
    )

    # LLM function
    def llm_model_func(prompt, system_prompt=None, history_messages=[], **kwargs):
        return openai_complete_if_cache(
            "gpt-4o-mini",
            prompt,
            system_prompt=system_prompt,
            history_messages=history_messages,
            api_key=api_key,
            **kwargs,
        )

    # Embedding function
    embedding_func = EmbeddingFunc(
        embedding_dim=3072,
        max_token_size=8192,
        func=lambda texts: openai_embed(
            texts,
            model="text-embedding-3-large",
            api_key=api_key,
        ),
    )

    # Init RAG
    rag = RAGAnything(
        config=config,
        llm_model_func=llm_model_func,
        vision_model_func=None,
        embedding_func=embedding_func,
    )

    # Grab first .txt email
    txt_files = list(Path(email_texts_directory).glob("*.txt"))
    if not txt_files:
        print("No TXT email files found in", email_texts_directory)
        return
    txt_path = str(txt_files[0])
    print(f"Processing TXT email: {txt_path}")

    # Process as plain text
    await rag.process_document_complete(
        file_path=txt_path,
        output_dir=rag_storage_directory,
        parse_method="txt"
    )

    # Query
    query = "What project is this email about?"
    result = await rag.aquery(query, mode="hybrid")
    print("Query:", query)
    print("Result:", result)

await example_raganything()
# Out:
# INFO: RAGAnything initialized with config:
# INFO:   Working directory: /content/drive/My Drive/MMV_email_rag/rag_storage
# INFO:   Parser: mineru
# INFO:   Parse method: txt
# INFO:   Multimodal processing - Image: False, Table: False, Equation: False
# INFO:   Max concurrent files: 1
# Processing TXT email: /content/drive/My Drive/MMV_email_rag/email_texts/First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# INFO: Parser 'mineru' installation verified
# INFO: Initializing LightRAG with parameters: {'working_dir': '/content/drive/My Drive/MMV_email_rag/rag_storage'}
# INFO: [_] Created new empty graph fiel: /content/drive/My Drive/MMV_email_rag/rag_storage/graph_chunk_entity_relation.graphml
# INFO: [_] Process 213 KV load full_docs with 0 records
# INFO: [_] Process 213 KV load text_chunks with 0 records
# INFO: [_] Process 213 KV load full_entities with 0 records
# INFO: [_] Process 213 KV load full_relations with 0 records
# INFO: [_] Process 213 KV load llm_response_cache with 0 records
# INFO: [_] Process 213 doc status load doc_status with 0 records
# INFO: [_] Process 213 KV load parse_cache with 2 records
# INFO: Multimodal processors initialized with context support
# INFO: Available processors: ['generic']
# INFO: Context configuration: ContextConfig(context_window=1, context_mode='page', max_context_tokens=2000, include_headers=True, include_captions=True, filter_content_types=['text'])
# INFO: LightRAG, parse cache, and multimodal processors initialized
# INFO: Starting complete document processing: /content/drive/My Drive/MMV_email_rag/email_texts/First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# INFO: Starting document parsing: /content/drive/My Drive/MMV_email_rag/email_texts/First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# INFO: Using mineru parser with method: txt
# INFO: Using generic parser for .txt file (method=txt)...
# WARNING:root:WenQuanYi font not found at /usr/share/fonts/wqy-microhei/wqy-microhei.ttc. Chinese characters may not render correctly.
# WARNING:root:[MinerU] WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# INFO: Parsing /content/drive/My Drive/MMV_email_rag/email_texts/First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt complete! Extracted 3 content blocks
# INFO: Stored parsing result in cache: 921f3e3916938044658e262f85fa068e
# INFO:
# Content Information:
# INFO: * Total blocks in content_list: 3
# INFO: * Content block types:
# INFO:   - text: 3
# INFO: Content separation complete:
# INFO:   - Text content length: 7324 characters
# INFO:   - Multimodal items count: 0
# INFO: Starting text content insertion into LightRAG...
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# INFO: Processing d-id: doc-b7137ab237eec33498e1953e36de8472
# INFO: Embedding func: 8 new workers initialized (Timeouts: Func: 30s, Worker: 60s, Health Check: 75s)
# INFO: LLM func: 4 new workers initialized (Timeouts: Func: 180s, Worker: 360s, Health Check: 375s)
# INFO:  == LLM cache == saving: default:extract:0ba701909f452bc25cdc391b31275d47
# INFO:  == LLM cache == saving: default:extract:28a7fb010ae95e53e74f48dfbcd1f3e2
# INFO:  == LLM cache == saving: default:extract:30ddce90a71281753124e5d8b61bfd1c
# INFO:  == LLM cache == saving: default:extract:d51b91063ad2c85c9d7e80d2e93d8d61
# INFO: Chunk 1 of 3 extracted 12 Ent + 6 Rel
# INFO:  == LLM cache == saving: default:extract:81d7cf8edcecda6c21a80b5c1f1bb740
# INFO: Chunk 2 of 3 extracted 9 Ent + 6 Rel
# INFO:  == LLM cache == saving: default:extract:24fdf382292b7992963869889c03e783
# INFO: Chunk 3 of 3 extracted 7 Ent + 5 Rel
# INFO: Merging stage 1/1: First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# INFO: Phase 1: Processing 25 entities from doc-b7137ab237eec33498e1953e36de8472 (async: 8)
# INFO: Phase 2: Processing 17 relations from doc-b7137ab237eec33498e1953e36de8472 (async: 8)
# INFO: Phase 3: Updating final 25(25+0) entities and  17 relations from doc-b7137ab237eec33498e1953e36de8472
# INFO: Completed merging: 25 entities, 0 extra entities, 17 relations
# INFO: [_] Writing graph with 25 nodes, 17 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
# INFO: Enqueued document processing pipeline stoped
# INFO: Text content insertion complete
# INFO: Document /content/drive/My Drive/MMV_email_rag/email_texts/First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt processing complete!
# INFO: Executing text query: What project is this email about?...
# INFO: Query mode: hybrid
# INFO:  == LLM cache == saving: hybrid:keywords:513ded5317f50ca8d1f61a4bb933ac2b
# WARNING: low_level_keywords is empty
# INFO: Query edges: Project, Email context (top_k:40, cosine:0.2)
# INFO: Global query: 16 entites, 14 relations
# INFO: Raw search results: 16 entities, 14 relations, 0 vector chunks
# INFO: After truncation: 16 entities, 14 relations
# INFO: Selecting 3 from 3 entity-related chunks by vector similarity
# INFO: Find no additional relations-related chunks from 14 relations
# INFO: Round-robin merged chunks: 3 -> 3 (deduplication: 0)
# WARNING: Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# INFO: Final context: 16 entities, 14 relations, 3 chunks
# INFO: chunks: E5/1 E5/2 E9/3
# INFO:  == LLM cache == saving: hybrid:query:28698a5529fca4b835a740dacb41623c
# INFO: Text query completed
# Query: What project is this email about?
# Result: The email is about the **First Merchants Bank Royal Oak** project. It is an invitation to bid on this project, which is being managed by PCI Industries, Inc. The email provides details about the bid due date and offers methods for bid submission.
#
# **References:**
# - [KG] First Merchants Bank Royal Oak
# - [KG] PCI Industries, Inc ~ First Merchants Bank Royal Oak
# - [DC] First Merchants Bank Royal Oak_ Invitation to bid on First Merchants Bank_1.txt
